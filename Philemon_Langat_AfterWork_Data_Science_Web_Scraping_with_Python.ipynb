# %% [markdown]
# <font color='#2F4F4F'>To use this notebook on Colaboratory, you will need to make a copy of it. Go to File > Save a Copy in Drive. You can then use the new copy that will appear in the new tab.</font>

# %% [markdown]
# # <font color='#2F4F4F'>AfterWork Data Science: Web Scraping with Python</font>

# %% [markdown]
# ##Background Information
# Together with a team of startup entrepreneurs, you decide to work on an idea that could
# change the way people search for jobs. You decide that job scraping could be the next
# big thing as there are actively many people looking for jobs in the country, in this case,
# Kenya.
# ##Problem Statement
# The problem is that there are many job listings which can not get visits for the target job
# seekers. While working in a team, your task as a data scientist for this project is to
# scrape for job titles and links and then put them in a single table that can be used by
# your team members to further build a job aggregator.
# You will be required to scrape for data from the following three technology webpages:
#
# <br>
# ● PigiaMe: https://www.pigiame.co.ke/it-software-jobs<br>
# ● MyJobMag: https://www.myjobmag.co.ke/jobs-by-field/information-technology<br>
# ● KenyaJob:
# https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133<br>

# %% [markdown]
# ##Success Criteria
#
# The deliverable will be a single table containing job titles and links that can be used to further build a job aggregator

# %% [markdown]
# ## <font color='#2F4F4F'>Prerequisites</font>

# %%
# We first import the required libraries
# ---
#
import pandas as pd             # library for data manupation
import requests                 # library for fetching a web page 
from bs4 import BeautifulSoup   # library for extrating contents from a webpage

# %% [markdown]
# ## <font color='#2F4F4F'>Step 1: Obtaining our Data</font>

# %%
# PigiaMe: https://www.pigiame.co.ke/it-software-jobs
# ---
#

pigia_url_list = [
  'https://www.pigiame.co.ke/it-software-jobs',
  'https://www.pigiame.co.ke/it-software-jobs?page=2',
  'https://www.pigiame.co.ke/it-software-jobs?page=3',
  'https://www.pigiame.co.ke/it-software-jobs?page=4'
]

# %%
# MyJobMag: https://www.myjobmag.co.ke/jobs-by-field/information-technology
# ---
#
myj_url_list = [
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/2',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/3',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/4',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/5',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/6',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/7',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/8',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/9',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/10',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/11',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/12',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/13',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/14',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/15',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/16',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/17',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/18',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/19',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/20',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/21',
  'https://www.myjobmag.co.ke/jobs-by-field/information-technology/22'

]

myj_base_url = 'https://www.myjobmag.co.ke'

# %%
# KenyanJob: https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133
# ---
#

kj_url_list = [
  'https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133',
  'https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133&page=1',
  'https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133&page=2'

]

kj_base_url = 'https://www.kenyajob.com'

# %% [markdown]
# ## <font color='#2F4F4F'>Step 2: Parsing & Extracting required elements</font>

# %% [markdown]
# <font color=green><i>NOTE: ....Solution notebook sections sequence was modified because the search results are all on multiple pages and 'for loop' is needed to parse and extract data from each website...</i></font>

# %% [markdown]
# ####pigiame scraper....

# %%
#temp data holders
job_titles  = list()
job_links = list()

# %%
# Parsing our document: pigia_me
# ---
# 
for u in pigia_url_list:
  #Fetch page 
  pigia_me = requests.get(u)
  
  # Parsing data using BeautifulSoup
  soup1 = BeautifulSoup(pigia_me.text, "html.parser")

  #Extract the needed elements
  tit1 = soup1.find_all('div', {'class': 'listing-card__header__title'})
  lin1 = soup1.find_all('a', {'class': "listing-card__inner"})

  for t in tit1:
    job_titles.append(t.get_text()) 

  for l in lin1:
    job_links.append(l.get('href'))

# %%
#filter out unwanted text ['\n']
t2 = list()
for t in job_titles:
    t2.append(t.replace("\n", ""))
#t2

# %%
#Load data into a df
df = pd.DataFrame({"Job Title": t2, "Link": job_links})
pd.set_option('display.max_colwidth', None)
df
# Out:
#                                                      Job Title  \
# 0                                   Senior Engineering Manager
# 1                         Senior Cloud Infrastructure Engineer
# 2       Junior Research Assistant-Data and Information Systems
# 3              Research Associate-Data and Information Systems
# 4                                               Data Scientist
# 5                                         AI Software Engineer
# 6                                      Data Analytics Engineer
# 7                                                 Data Manager
# 8                                     Senior Software Engineer
# 9                                        Data Analyst - Kisumu
# 10                                       Data Analyst - Nakuru
# 11                                      Data Analyst - Eldoret
# 12                                        Data Analyst - Thika
# 13                                      Data Analyst - Mombasa
# 14                                      Data Analyst - Nairobi
# 15                        Bioinformatic and Software Developer
# 16                            IT Sales - Cybersecurity & Cloud
# 17                               Executive, Support & Services
# 18                                Software Development Trainer
# 19                  UI/UX & Frontend Developer – Limuru, Kenya
# 20                            IT Sales - Cybersecurity & Cloud
# 21                          Wordpress and Shopify Web Designer
# 22                              Entry level Software Developer
# 23                                                Data Analyst
# 24                    Business Intelligence & Research Analyst
# 25                               Supervisor Medical Data Entry
# 26           Information Services Assistant (Business Systems)
# 27                                    Senior Software Engineer
# 28                                             Data Specialist
# 29  Supervisor – Data Warehouse & BI (Database Administration)
# 30     Officer – Data Warehouse & BI (Database Administration)
# 31            SCM (Supply Chain Management) Support Specialist
# 32                                     Digital Account Manager
# 33                                 Digital Marketing Executive
# 34                 SEO Marketing and Google Adwords Specialist
# 35                                   Digital Marketing Manager
# 36                                         Computer Programmer
#
#                                                                                                  Link
# 0                               https://www.pigiame.co.ke/listings/senior-engineering-manager-5453736
# 1                     https://www.pigiame.co.ke/listings/senior-cloud-infrastructure-engineer-5453727
# 2   https://www.pigiame.co.ke/listings/junior-research-assistant-data-and-information-systems-5453464
# 3          https://www.pigiame.co.ke/listings/research-associate-data-and-information-systems-5453442
# 4                                           https://www.pigiame.co.ke/listings/data-scientist-5451538
# 5                                     https://www.pigiame.co.ke/listings/ai-software-engineer-5451531
# 6                                  https://www.pigiame.co.ke/listings/data-analytics-engineer-5451518
# 7                                             https://www.pigiame.co.ke/listings/data-manager-5447874
# 8                                 https://www.pigiame.co.ke/listings/senior-software-engineer-5439676
# 9                                      https://www.pigiame.co.ke/listings/data-analyst-kisumu-5437315
# 10                                     https://www.pigiame.co.ke/listings/data-analyst-nakuru-5437312
# 11                                    https://www.pigiame.co.ke/listings/data-analyst-eldoret-5437310
# 12                                      https://www.pigiame.co.ke/listings/data-analyst-thika-5437309
# 13                                    https://www.pigiame.co.ke/listings/data-analyst-mombasa-5437305
# 14                                    https://www.pigiame.co.ke/listings/data-analyst-nairobi-5437301
# 15                    https://www.pigiame.co.ke/listings/bioinformatic-and-software-developer-5427801
# 16                            https://www.pigiame.co.ke/listings/it-sales-cybersecurity-cloud-5427375
# 17                              https://www.pigiame.co.ke/listings/executive-support-services-5427355
# 18                            https://www.pigiame.co.ke/listings/software-development-trainer-5418174
# 19                    https://www.pigiame.co.ke/listings/uiux-frontend-developer-limuru-kenya-5412804
# 20                            https://www.pigiame.co.ke/listings/it-sales-cybersecurity-cloud-5411841
# 21                      https://www.pigiame.co.ke/listings/wordpress-and-shopify-web-designer-5403307
# 22                          https://www.pigiame.co.ke/listings/entry-level-software-developer-5388823
# 23                                            https://www.pigiame.co.ke/listings/data-analyst-5385663
# 24                  https://www.pigiame.co.ke/listings/business-intelligence-research-analyst-5383526
# 25                           https://www.pigiame.co.ke/listings/supervisor-medical-data-entry-5377399
# 26         https://www.pigiame.co.ke/listings/information-services-assistant-business-systems-5373228
# 27                                https://www.pigiame.co.ke/listings/senior-software-engineer-5322880
# 28                                         https://www.pigiame.co.ke/listings/data-specialist-5317646
# 29    https://www.pigiame.co.ke/listings/supervisor-data-warehouse-bi-database-administration-5311821
# 30       https://www.pigiame.co.ke/listings/officer-data-warehouse-bi-database-administration-5311814
# 31          https://www.pigiame.co.ke/listings/scm-supply-chain-management-support-specialist-5288214
# 32                                 https://www.pigiame.co.ke/listings/digital-account-manager-5203287
# 33                             https://www.pigiame.co.ke/listings/digital-marketing-executive-5203258
# 34             https://www.pigiame.co.ke/listings/seo-marketing-and-google-adwords-specialist-5123163
# 35                               https://www.pigiame.co.ke/listings/digital-marketing-manager-5123105
# 36                                     https://www.pigiame.co.ke/listings/computer-programmer-4956430

# %% [markdown]
# ####my_job_mag scraper....

# %%
#temp data holders
job_titles  = list()
job_links = list()

# %%
for u in myj_url_list:
  #Fetch page
  source = requests.get(u)
  
  # Parsing data using BeautifulSoup
  soup1 = BeautifulSoup(source.text, "html.parser")

  #Extract the needed elements
  tit1 = soup1.find_all('li', {'class': "mag-b"})

  for t in tit1:
    job_titles.append((t.get_text()).replace("\n", ""))
    job_links.append(myj_base_url + t.a.get('href'))

# %%
df2 = pd.DataFrame({"Job Title": job_titles, "Link": job_links})
pd.set_option('display.max_colwidth', None)
df2
# Out:
#                                                            Job Title  \
# 0      M-Pesa Africa - Digital Workspace Engineer at Safaricom Kenya
# 1                                     Senior UX Researcher at Wasoko
# 2                             ICT Sales Representative at HCS Africa
# 3     Cybersecurity Specialist, Security Awareness at KCB Bank Kenya
# 4                        Change Evaluation Analyst at KCB Bank Kenya
# ..                                                               ...
# 391                            Hardware QA Engineer at Koko Networks
# 392                     Support Engineer Internship at Koko Networks
# 393     Acquiring Implementation & Tech Support at Absa Bank Limited
# 394          Solution Architect Area Chapter Lead at Safaricom Kenya
# 395  Principal Engineer Cyber Prevent and Defense at Safaricom Kenya
#
#                                                                                               Link
# 0          https://www.myjobmag.co.ke/job/m-pesa-africa-digital-workspace-engineer-safaricom-kenya
# 1                                       https://www.myjobmag.co.ke/job/senior-ux-researcher-wasoko
# 2                                           https://www.myjobmag.co.ke/job/hcs-africa-hcs-africa-1
# 3      https://www.myjobmag.co.ke/job/cybersecurity-specialist-security-awareness-kcb-bank-kenya-1
# 4                        https://www.myjobmag.co.ke/job/change-evaluation-analyst-kcb-bank-kenya-2
# ..                                                                                             ...
# 391                            https://www.myjobmag.co.ke/job/hardware-qa-engineer-koko-networks-2
# 392                       https://www.myjobmag.co.ke/job/support-engineer-internship-koko-networks
# 393       https://www.myjobmag.co.ke/job/acquiring-implementation-tech-support-absa-bank-limited-2
# 394            https://www.myjobmag.co.ke/job/solution-architect-area-chapter-lead-safaricom-kenya
# 395  https://www.myjobmag.co.ke/job/principal-engineer-cyber-prevent-and-defense-safaricom-kenya-2
#
# [396 rows x 2 columns]

# %% [markdown]
# ####kenyan_job scraper....

# %%
#temp data holders
job_titles  = list()
job_links = list()

# %%
for u in kj_url_list:
  #Fetch the page
  source = requests.get(u)
  
  # Parsing data using BeautifulSoup
  soup1 = BeautifulSoup(source.text, "html.parser")

  #Extract the needed elements
  tit1 = soup1.find_all('div', {'class': "col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title"})

  for t in tit1:
    job_titles.append(t.a.get_text())
    job_links.append(kj_base_url + t.a.get('href'))

# %%
df3 = pd.DataFrame({"Job Title": job_titles, "Link": job_links})
pd.set_option('display.max_colwidth', None)
df3
# Out:
#                                                           Job Title  \
# 0                        JAVA EE / JAVA 8 Developer with SQL Skills
# 1                                     Senior Freelance Web Designer
# 2                                         Sales and Marketing Agent
# 3                                          Accountant/Administrator
# 4                           CCTV and Fire Alarms Systems Technician
# 5                           CCTV and Fire Alarms Systems Technician
# 6                           Information Technology Sales Specialist
# 7                                         AWS Cloud Architect (M/F)
# 8                                     AWS Solutions Architect (M/F)
# 9                                   AZURE Solutions Architect (M/F)
# 10                                            Cloud Architect (M/F)
# 11                Cloud Computing and Virtualization Engineer (M/F)
# 12                                             Cloud Engineer (M/F)
# 13                              Cloud Microservices Architect (M/F)
# 14                                 Cloud System Administrator (M/F)
# 15                                    Cloud System Integrator (M/F)
# 16                                    Cyber Security Engineer (M/F)
# 17                                        DATASTAGE Architect (M/F)
# 18                                          GENESYS Architect (M/F)
# 19                                          Network Architect (M/F)
# 20                                          ANGULAR Developer (M/F)
# 21                                            DevOps Engineer (M/F)
# 22                                           DOTNET Developer (M/F)
# 23                                              IOS Developer (M/F)
# 24                                             JAVA Developer (M/F)
# 25                                         JAVA JEE Developer (M/F)
# 26                                       JAVASCRIPT Developer (M/F)
# 27                                           KOTLIN Developer (M/F)
# 28                                          LARAVEL Developer (M/F)
# 29                                          NODE.JS Developer (M/F)
# 30                                      OBJECTIVE-C Developer (M/F)
# 31                                              PHP Developer (M/F)
# 32                                           PYTHON Developer (M/F)
# 33                                                  QA Tester (M/F)
# 34                                            REACT Developer (M/F)
# 35                                    RUBY ON RAILS Developer (M/F)
# 36                                            SWIFT Developer (M/F)
# 37                               Test and Validation Engineer (M/F)
# 38                                   Test Automation Engineer (M/F)
# 39                                           UX / UI Designer (M/F)
# 40                                               Software Developer
# 41                                  Freelance Product Photographers
# 42                                          Motion Graphic Designer
# 43                              OpenStack Technical Support Manager
# 44                     Senior Web Developer - Workplace Engineering
# 45                                       IoT Sales Director - Linux
# 46  Global Technical Director, Canonical Managed OpenStack Services
# 47                                                  Product Manager
# 48       Senior Product Manager - Microsoft FAST & MSAI Experiences
# 49                              Principal Group Engineering Manager
# 50                                             Software Engineer II
# 51                                 Senior Executive, Climate Change
# 52                                             Global Director, HSE
# 53                                           Senior Product Manager
# 54                                             Senior Data Engineer
#
#                                                                                                                   Link
# 0                              https://www.kenyajob.com/job-vacancies-kenya/java-ee-java-8-developer-sql-skills-130458
# 1                                    https://www.kenyajob.com/job-vacancies-kenya/senior-freelance-web-designer-130459
# 2                                            https://www.kenyajob.com/job-vacancies-kenya/sales-marketing-agent-131641
# 3                                          https://www.kenyajob.com/job-vacancies-kenya/accountantadministrator-126803
# 4                              https://www.kenyajob.com/job-vacancies-kenya/cctv-fire-alarms-systems-technician-127106
# 5                              https://www.kenyajob.com/job-vacancies-kenya/cctv-fire-alarms-systems-technician-127107
# 6                          https://www.kenyajob.com/job-vacancies-kenya/information-technology-sales-specialist-129253
# 7                                           https://www.kenyajob.com/job-vacancies-kenya/aws-cloud-architect-mf-129511
# 8                                       https://www.kenyajob.com/job-vacancies-kenya/aws-solutions-architect-mf-129512
# 9                                     https://www.kenyajob.com/job-vacancies-kenya/azure-solutions-architect-mf-129513
# 10                                              https://www.kenyajob.com/job-vacancies-kenya/cloud-architect-mf-129514
# 11                      https://www.kenyajob.com/job-vacancies-kenya/cloud-computing-virtualization-engineer-mf-129515
# 12                                               https://www.kenyajob.com/job-vacancies-kenya/cloud-engineer-mf-129516
# 13                                https://www.kenyajob.com/job-vacancies-kenya/cloud-microservices-architect-mf-129517
# 14                                   https://www.kenyajob.com/job-vacancies-kenya/cloud-system-administrator-mf-129518
# 15                                      https://www.kenyajob.com/job-vacancies-kenya/cloud-system-integrator-mf-129519
# 16                                      https://www.kenyajob.com/job-vacancies-kenya/cyber-security-engineer-mf-129520
# 17                                          https://www.kenyajob.com/job-vacancies-kenya/datastage-architect-mf-129521
# 18                                            https://www.kenyajob.com/job-vacancies-kenya/genesys-architect-mf-129522
# 19                                            https://www.kenyajob.com/job-vacancies-kenya/network-architect-mf-129523
# 20                                            https://www.kenyajob.com/job-vacancies-kenya/angular-developer-mf-129524
# 21                                              https://www.kenyajob.com/job-vacancies-kenya/devops-engineer-mf-129525
# 22                                             https://www.kenyajob.com/job-vacancies-kenya/dotnet-developer-mf-129526
# 23                                                https://www.kenyajob.com/job-vacancies-kenya/ios-developer-mf-129527
# 24                                               https://www.kenyajob.com/job-vacancies-kenya/java-developer-mf-129528
# 25                                           https://www.kenyajob.com/job-vacancies-kenya/java-jee-developer-mf-129529
# 26                                         https://www.kenyajob.com/job-vacancies-kenya/javascript-developer-mf-129530
# 27                                             https://www.kenyajob.com/job-vacancies-kenya/kotlin-developer-mf-129531
# 28                                            https://www.kenyajob.com/job-vacancies-kenya/laravel-developer-mf-129532
# 29                                             https://www.kenyajob.com/job-vacancies-kenya/nodejs-developer-mf-129533
# 30                                        https://www.kenyajob.com/job-vacancies-kenya/objective-c-developer-mf-129534
# 31                                                https://www.kenyajob.com/job-vacancies-kenya/php-developer-mf-129535
# 32                                             https://www.kenyajob.com/job-vacancies-kenya/python-developer-mf-129536
# 33                                                    https://www.kenyajob.com/job-vacancies-kenya/qa-tester-mf-129537
# 34                                              https://www.kenyajob.com/job-vacancies-kenya/react-developer-mf-129538
# 35                                      https://www.kenyajob.com/job-vacancies-kenya/ruby-on-rails-developer-mf-129539
# 36                                              https://www.kenyajob.com/job-vacancies-kenya/swift-developer-mf-129540
# 37                                     https://www.kenyajob.com/job-vacancies-kenya/test-validation-engineer-mf-129541
# 38                                     https://www.kenyajob.com/job-vacancies-kenya/test-automation-engineer-mf-129542
# 39                                               https://www.kenyajob.com/job-vacancies-kenya/ux-ui-designer-mf-129543
# 40                                              https://www.kenyajob.com/job-vacancies-kenya/software-developer-130123
# 41                                 https://www.kenyajob.com/job-vacancies-kenya/freelance-product-photographers-130438
# 42                                         https://www.kenyajob.com/job-vacancies-kenya/motion-graphic-designer-130876
# 43                             https://www.kenyajob.com/job-vacancies-kenya/openstack-technical-support-manager-129771
# 44                      https://www.kenyajob.com/job-vacancies-kenya/senior-web-developer-workplace-engineering-129772
# 45                                        https://www.kenyajob.com/job-vacancies-kenya/iot-sales-director-linux-129773
# 46  https://www.kenyajob.com/job-vacancies-kenya/global-technical-director-canonical-managed-openstack-services-129774
# 47                                                 https://www.kenyajob.com/job-vacancies-kenya/product-manager-128272
# 48          https://www.kenyajob.com/job-vacancies-kenya/senior-product-manager-microsoft-fast-msai-experiences-128273
# 49                             https://www.kenyajob.com/job-vacancies-kenya/principal-group-engineering-manager-128274
# 50                                            https://www.kenyajob.com/job-vacancies-kenya/software-engineer-ii-128276
# 51                                 https://www.kenyajob.com/job-vacancies-kenya/senior-executive-climate-change-128084
# 52                                             https://www.kenyajob.com/job-vacancies-kenya/global-director-hse-128085
# 53                                          https://www.kenyajob.com/job-vacancies-kenya/senior-product-manager-128089
# 54                                            https://www.kenyajob.com/job-vacancies-kenya/senior-data-engineer-128091

# %% [markdown]
# ## <font color='#2F4F4F'>Step 3: Saving our Data</font>

# %%
# Saving the scraped contents in a dataframe and preview our data
# ---
#
full_df = pd.concat([df, df2, df3], ignore_index=True)
full_df.head(30)
# Out:
#                                                      Job Title  \
# 0                                   Senior Engineering Manager
# 1                         Senior Cloud Infrastructure Engineer
# 2       Junior Research Assistant-Data and Information Systems
# 3              Research Associate-Data and Information Systems
# 4                                               Data Scientist
# 5                                         AI Software Engineer
# 6                                      Data Analytics Engineer
# 7                                                 Data Manager
# 8                                     Senior Software Engineer
# 9                                        Data Analyst - Kisumu
# 10                                       Data Analyst - Nakuru
# 11                                      Data Analyst - Eldoret
# 12                                        Data Analyst - Thika
# 13                                      Data Analyst - Mombasa
# 14                                      Data Analyst - Nairobi
# 15                        Bioinformatic and Software Developer
# 16                            IT Sales - Cybersecurity & Cloud
# 17                               Executive, Support & Services
# 18                                Software Development Trainer
# 19                  UI/UX & Frontend Developer – Limuru, Kenya
# 20                            IT Sales - Cybersecurity & Cloud
# 21                          Wordpress and Shopify Web Designer
# 22                              Entry level Software Developer
# 23                                                Data Analyst
# 24                    Business Intelligence & Research Analyst
# 25                               Supervisor Medical Data Entry
# 26           Information Services Assistant (Business Systems)
# 27                                    Senior Software Engineer
# 28                                             Data Specialist
# 29  Supervisor – Data Warehouse & BI (Database Administration)
#
#                                                                                                  Link
# 0                               https://www.pigiame.co.ke/listings/senior-engineering-manager-5453736
# 1                     https://www.pigiame.co.ke/listings/senior-cloud-infrastructure-engineer-5453727
# 2   https://www.pigiame.co.ke/listings/junior-research-assistant-data-and-information-systems-5453464
# 3          https://www.pigiame.co.ke/listings/research-associate-data-and-information-systems-5453442
# 4                                           https://www.pigiame.co.ke/listings/data-scientist-5451538
# 5                                     https://www.pigiame.co.ke/listings/ai-software-engineer-5451531
# 6                                  https://www.pigiame.co.ke/listings/data-analytics-engineer-5451518
# 7                                             https://www.pigiame.co.ke/listings/data-manager-5447874
# 8                                 https://www.pigiame.co.ke/listings/senior-software-engineer-5439676
# 9                                      https://www.pigiame.co.ke/listings/data-analyst-kisumu-5437315
# 10                                     https://www.pigiame.co.ke/listings/data-analyst-nakuru-5437312
# 11                                    https://www.pigiame.co.ke/listings/data-analyst-eldoret-5437310
# 12                                      https://www.pigiame.co.ke/listings/data-analyst-thika-5437309
# 13                                    https://www.pigiame.co.ke/listings/data-analyst-mombasa-5437305
# 14                                    https://www.pigiame.co.ke/listings/data-analyst-nairobi-5437301
# 15                    https://www.pigiame.co.ke/listings/bioinformatic-and-software-developer-5427801
# 16                            https://www.pigiame.co.ke/listings/it-sales-cybersecurity-cloud-5427375
# 17                              https://www.pigiame.co.ke/listings/executive-support-services-5427355
# 18                            https://www.pigiame.co.ke/listings/software-development-trainer-5418174
# 19                    https://www.pigiame.co.ke/listings/uiux-frontend-developer-limuru-kenya-5412804
# 20                            https://www.pigiame.co.ke/listings/it-sales-cybersecurity-cloud-5411841
# 21                      https://www.pigiame.co.ke/listings/wordpress-and-shopify-web-designer-5403307
# 22                          https://www.pigiame.co.ke/listings/entry-level-software-developer-5388823
# 23                                            https://www.pigiame.co.ke/listings/data-analyst-5385663
# 24                  https://www.pigiame.co.ke/listings/business-intelligence-research-analyst-5383526
# 25                           https://www.pigiame.co.ke/listings/supervisor-medical-data-entry-5377399
# 26         https://www.pigiame.co.ke/listings/information-services-assistant-business-systems-5373228
# 27                                https://www.pigiame.co.ke/listings/senior-software-engineer-5322880
# 28                                         https://www.pigiame.co.ke/listings/data-specialist-5317646
# 29    https://www.pigiame.co.ke/listings/supervisor-data-warehouse-bi-database-administration-5311821

# %%
#preview df tail data
full_df.tail(20)
# Out:
#                                                            Job Title  \
# 468                                    RUBY ON RAILS Developer (M/F)
# 469                                            SWIFT Developer (M/F)
# 470                               Test and Validation Engineer (M/F)
# 471                                   Test Automation Engineer (M/F)
# 472                                           UX / UI Designer (M/F)
# 473                                               Software Developer
# 474                                  Freelance Product Photographers
# 475                                          Motion Graphic Designer
# 476                              OpenStack Technical Support Manager
# 477                     Senior Web Developer - Workplace Engineering
# 478                                       IoT Sales Director - Linux
# 479  Global Technical Director, Canonical Managed OpenStack Services
# 480                                                  Product Manager
# 481       Senior Product Manager - Microsoft FAST & MSAI Experiences
# 482                              Principal Group Engineering Manager
# 483                                             Software Engineer II
# 484                                 Senior Executive, Climate Change
# 485                                             Global Director, HSE
# 486                                           Senior Product Manager
# 487                                             Senior Data Engineer
#
#                                                                                                                    Link
# 468                                      https://www.kenyajob.com/job-vacancies-kenya/ruby-on-rails-developer-mf-129539
# 469                                              https://www.kenyajob.com/job-vacancies-kenya/swift-developer-mf-129540
# 470                                     https://www.kenyajob.com/job-vacancies-kenya/test-validation-engineer-mf-129541
# 471                                     https://www.kenyajob.com/job-vacancies-kenya/test-automation-engineer-mf-129542
# 472                                               https://www.kenyajob.com/job-vacancies-kenya/ux-ui-designer-mf-129543
# 473                                              https://www.kenyajob.com/job-vacancies-kenya/software-developer-130123
# 474                                 https://www.kenyajob.com/job-vacancies-kenya/freelance-product-photographers-130438
# 475                                         https://www.kenyajob.com/job-vacancies-kenya/motion-graphic-designer-130876
# 476                             https://www.kenyajob.com/job-vacancies-kenya/openstack-technical-support-manager-129771
# 477                      https://www.kenyajob.com/job-vacancies-kenya/senior-web-developer-workplace-engineering-129772
# 478                                        https://www.kenyajob.com/job-vacancies-kenya/iot-sales-director-linux-129773
# 479  https://www.kenyajob.com/job-vacancies-kenya/global-technical-director-canonical-managed-openstack-services-129774
# 480                                                 https://www.kenyajob.com/job-vacancies-kenya/product-manager-128272
# 481          https://www.kenyajob.com/job-vacancies-kenya/senior-product-manager-microsoft-fast-msai-experiences-128273
# 482                             https://www.kenyajob.com/job-vacancies-kenya/principal-group-engineering-manager-128274
# 483                                            https://www.kenyajob.com/job-vacancies-kenya/software-engineer-ii-128276
# 484                                 https://www.kenyajob.com/job-vacancies-kenya/senior-executive-climate-change-128084
# 485                                             https://www.kenyajob.com/job-vacancies-kenya/global-director-hse-128085
# 486                                          https://www.kenyajob.com/job-vacancies-kenya/senior-product-manager-128089
# 487                                            https://www.kenyajob.com/job-vacancies-kenya/senior-data-engineer-128091
